# %%
# 1 
csv_files = ['movies.csv', 'ratings.csv', 'links.csv', 'tags.csv']
print(f'no of CSV files: {len(csv_files)}')
# Out:
# no of CSV files: 4

# %%
# 2

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\admin\\Documents\\resumes\\links.csv")
df
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
d1
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
d1.shape
# Out:
# (9742, 3)

# %%
d2 = pd.read_csv("C:\\Users\\admin\\Documents\\resumes\\ratings.csv")
d2.shape
# Out:
# (100836, 4)

# %%
d2.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#Which movie has recieved maximum number of user ratings?

# %%
d1
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
d1.groupby('movieId')['title'].max()
# Out:
# movieId
# 1                                  Toy Story (1995)
# 2                                    Jumanji (1995)
# 3                           Grumpier Old Men (1995)
# 4                          Waiting to Exhale (1995)
# 5                Father of the Bride Part II (1995)
#                             ...
# 193581    Black Butler: Book of the Atlantic (2017)
# 193583                 No Game No Life: Zero (2017)
# 193585                                 Flint (2017)
# 193587          Bungo Stray Dogs: Dead Apple (2018)
# 193609          Andrew Dice Clay: Dice Rules (1991)
# Name: title, Length: 9742, dtype: object

# %%
d = pd.merge(d1,d2,on = 'movieId', how = 'left')

# %%
d
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# ...

# %%
d.groupby('title')['rating'].max()
# Out:
# title
# '71 (2014)                                   4.0
# 'Hellboy': The Seeds of Creation (2004)      4.0
# 'Round Midnight (1986)                       3.5
# 'Salem's Lot (2004)                          5.0
# 'Til There Was You (1997)                    5.0
#                                             ...
# eXistenZ (1999)                              5.0
# xXx (2002)                                   4.0
# xXx: State of the Union (2005)               2.5
# ¡Three Amigos! (1986)                        5.0
# À nous la liberté (Freedom for Us) (1931)    1.0
# Name: rating, Length: 9719, dtype: float64

# %%
d[d['rating']>=5.0]
# Out:
#         movieId                             title  \
# 9             1                  Toy Story (1995)
# 12            1                  Toy Story (1995)
# 13            1                  Toy Story (1995)
# 16            1                  Toy Story (1995)
# 19            1                  Toy Story (1995)
# ...         ...                               ...
# 100787   187593                 Deadpool 2 (2018)
# 100790   187593                 Deadpool 2 (2018)
# 100791   187593                 Deadpool 2 (2018)
# 100801   187595    Solo: A Star Wars Story (2018)
# 100802   187717  Won't You Be My Neighbor? (2018)
#
#                                              genres  userId  rating  \
# 9       Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# 12      Adventure|Animation|Children|Comedy|Fantasy      40     5.0
# 13      Adventure|Animation|Children|Comedy|Fantasy      43     5.0
# 16      Adventure|Animation|Children|Comedy|Fantasy      46     5.0
# ...

# %%
ratings_count = d.groupby('title').size()

max_ratings_movie = ratings_count.idxmax()
max_ratings_count = ratings_count.max()

print(f"The movie  '{max_ratings_movie}' with {max_ratings_count} ratings.")
# Out:
# The movie  'Forrest Gump (1994)' with 329 ratings.

# %%
# Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
d3 = pd.read_csv("C:\\Users\\admin\\Documents\\resumes\\tags.csv")

# %%
d3
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
e = pd.merge(d1,d3 ,on ='movieId',how = 'inner')

# %%
e
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
e[e['title']=='Matrix, The (1999)']
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
# What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"

# %%
e[e['title']=="Judgment Day (1991)"]
# Out:
#       movieId                title  \
# 0           1  Judgment Day (1991)
# 1           1  Judgment Day (1991)
# 2           1  Judgment Day (1991)
# 3           2  Judgment Day (1991)
# 4           2  Judgment Day (1991)
# ...       ...                  ...
# 3678   187595  Judgment Day (1991)
# 3679   193565  Judgment Day (1991)
# 3680   193565  Judgment Day (1991)
# 3681   193565  Judgment Day (1991)
# 3682   193565  Judgment Day (1991)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# 4                      Adventure|Children|Fantasy      62  magic board game
# ...                                           ...     ...               ...
# ...

# %%
q = pd.merge(d1,d2, on='movieId')

# %%
#movie_title = "Terminator 2: Judgment Day (1991)"
ratings_for_movie = q[q['title'] == 'Terminator 2: Judgment Day (1991)']['rating']

# %%
ratings_for_movie.mean()
# Out:
# 3.970982142857143

# %%
# How does the data distribution of user ratings for "Fight Club (1999)" movie looks like

# %%
q['title'].value_counts().plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#1  Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings. 
2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
3. Filter only those movies which have more than 50 user ratings (i.e. > 50).

Above steps will make sure that your data contains only those movies which has recieved more than 50 user ratings.
Which movie is the most popular based on  average user ratings?

# Answer this question only after applying the above mentioned "Mandatory Operration".

# %%
l =q.groupby(['movieId','rating'])['userId'].agg(['mean','count'])  
l
# Out:
#                       mean  count
# movieId rating
# 1       0.5      76.000000      1
#         1.5     462.000000      1
#         2.0     242.333333      6
#         2.5     367.375000      8
#         3.0     285.852941     34
# ...                    ...    ...
# 193581  4.0     184.000000      1
# 193583  3.5     184.000000      1
# 193585  3.5     184.000000      1
# 193587  3.5     184.000000      1
# 193609  4.0     331.000000      1
#
# [30417 rows x 2 columns]

# %%
m = pd.merge(l,q,on= 'movieId',how = 'inner')
m[(m['rating']>=5.0)] 
most = m.sort_values('rating',ascending = True).head(5)

# %%
ratings_groupes = d2.groupby(['movieId','rating'])['userId'].agg(['mean','count'])

# %%
gr = pd.merge(ratings_groupes,d2,on = 'movieId')

# %%
gp = gr[gr['rating']>=5.0]

# %%
most_popular_movie = d.loc[d['rating'].idxmax()]

# %%
print(f"The most popular movie based on average user ratings is '{most_popular_movie['title']}' with an average rating of {most_popular_movie['rating']:.2f}.")
# Out:
# The most popular movie based on average user ratings is 'Toy Story (1995)' with an average rating of 5.00.

# %%
#Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
ratings_grouped =d2.groupby('movieId').size().reset_index(name='ratings_count')

merged_df = pd.merge(ratings_grouped, d1, on='movieId')

top_5_movies = merged_df.sort_values(by='ratings_count', ascending=False).head()

print("Top 5 popular movies based on the number of user ratings:")
print(top_5_movies[['title', 'ratings_count']])
# Out:
# Top 5 popular movies based on the number of user ratings:
#                                  title  ratings_count
# 314                Forrest Gump (1994)            329
# 277   Shawshank Redemption, The (1994)            317
# 257                Pulp Fiction (1994)            307
# 510   Silence of the Lambs, The (1991)            279
# 1938                Matrix, The (1999)            278

# %%
d1
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
# Which Sci-Fi movie is "third most popular" based on the number of user ratings

# %%
a = d[d['genres'].str.contains('Sci-Fi')]
rat = d.groupby('movieId').size().reset_index(name='ratings_count')
sc = pd.merge(rat,a,on = 'movieId')
sor = sc.sort_values('rating',ascending = False)
tr = sor.iloc[0]
print(f"ggvhihv'{tr['title']}'with {tr['ratings_count']}rating.")
# Out:
# ggvhihv'Metropolis (1927)'with 21rating.

# %%
w = d[(d['genres']=='Sci-Fi')  & (d['rating']>=5.0)].sort_values(by = 'rating',ascending = False)

# %%
x = pd.merge(w,d,on='movieId')
x
# Out:
#      movieId                                title_x genres_x  userId_x  \
# 0       4813             When Worlds Collide (1951)   Sci-Fi     186.0
# 1       5468       20 Million Miles to Earth (1957)   Sci-Fi     377.0
# 2       5919                         Android (1982)   Sci-Fi       3.0
# 3       5919                         Android (1982)   Sci-Fi       3.0
# 4     112623  Dawn of the Planet of the Apes (2014)   Sci-Fi     380.0
# ..       ...                                    ...      ...       ...
# 226   176371               Blade Runner 2049 (2017)   Sci-Fi     567.0
# 227   176371               Blade Runner 2049 (2017)   Sci-Fi     567.0
# 228   176371               Blade Runner 2049 (2017)   Sci-Fi     567.0
# 229   176371               Blade Runner 2049 (2017)   Sci-Fi     567.0
# 230   176371               Blade Runner 2049 (2017)   Sci-Fi     567.0
#
#      rating_x   timestamp_x                                title_y genres_y  \
# ...

# %%
df.imdbId.max()
# Out:
# 8391976

# %%
# Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating

# %%
l = pd.merge(df,d,on ='movieId')
l

# %%
sci_fi_movies = l[l['genres'] == 'Sci-Fi']

max_rated_sci_fi = sci_fi_movies.loc[sci_fi_movies['rating'].idxmax()]

print(f"The Sci-Fi movie  '{max_rated_sci_fi['title']}' with {max_rated_sci_fi['rating']} rating.")
# Out:
# The Sci-Fi movie  'When Worlds Collide (1951)' with 5.0 rating.

# %%
w = d[(d['genres']=='Sci-Fi')  & (d['rating']>=5.0)]

# %%
w.head()
# Out:
#        movieId                                  title  genres  userId  rating  \
# 63549     4813             When Worlds Collide (1951)  Sci-Fi   186.0     5.0
# 67452     5468       20 Million Miles to Earth (1957)  Sci-Fi   377.0     5.0
# 68921     5919                         Android (1982)  Sci-Fi     3.0     5.0
# 97337   112623  Dawn of the Planet of the Apes (2014)  Sci-Fi   380.0     5.0
# 99557   147376   Doctor Who: A Christmas Carol (2010)  Sci-Fi   380.0     5.0
#
#           timestamp
# 63549  1.031080e+09
# 67452  1.340342e+09
# 68921  1.306464e+09
# 97337  1.493474e+09
# 99557  1.493422e+09
